# %%
print('Hello World!!!!')
# Out:
# Hello World!!!!

# %% [markdown]
# ## Nozioni di base su Markdown
# questo è un markodwn, è un linguaggio usato come metatesto
# **grassetto**
# *corsivo*
# 'codice'

# %%
2+2
"ciao"       #stampa solo il risultato dell'ultima riga
# Out:
# 'ciao'

# %%
2+2, "ciaooo"      #non stampa veramente, per farlo devo usare print
# Out:
# (4, 'ciaooo')

# %%
print(2+2)
print("ciaoo")
# Out:
# 4
# ciaoo

# %%
# %cd
# Out:
# C:\Users\samue

# %%
# %timeit [n*n for n in range(200)]    #ci dice quanto tempo impiega una singola operazione

# %%timeit    #ci dice quanto tempo impiegano tutte le linee successive
# Out:
# 6.62 μs ± 151 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# <!-- "questo è un markodwn" -->
